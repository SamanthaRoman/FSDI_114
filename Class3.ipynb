# %%
# Simplified implementation of Queue (using built-in structures)

class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, value):
        self.items.insert(0,value)

    def dequeue(self):
        return self.items.pop()

# nice to have methods 

    def peek(self):
        return self.items[len(sel.items)-1]

    def size(self):
        return len(self.items)

    def is_empty(self):
        return sel.items == []

# %%
# From scratch implemetation of Queue

class QueueII:
    class __Node:
        def __init__(self,data)
            self.data = data
            self.below = None             # first we track the previous
            # Should node track the previous, the next or both (Nodes)

    def __init__(self)
    # Should we track the rear, the front or both?
        self.rear = None
        self.front = None .
        

    def enqueue(self, value):             
       #recieve a value and "enqueues" it at the rear
        new_node = self.__node(value)
        if not self.rear:
            self.rear = self.rear = self.front = new_node
        else:
            self.rear.next = new_node

    def dequeue(self):
        # removes and returns the element at the front
        if not self.front:
            raise IndexError("Queue is empty")
        value = self.front.data
        self.front = self.front.next
        return value

# Nice to have
    def peek(self):
        # returns, but does not remove, the data at the front node
        return self.front.data

    def size(self):
        #returns the total number of Nodes in the queue
        count = 0
        current = self.front
        while current:
            current = current.next
            count += 0
        return count

    def is_empty(self):
        # Returns True when the Queue is empty, False otherwise
        return self.front == None

class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

        def __init__(self):
            self.head = None

        def __str__(self):
            out = "["
            current = self.head
            if current:
                out += "%s" % current.data
                current = current.next
            out += "]"
            return out

        def append(self, value):
            new_node = self.__Node(value)
            current = self.head
            if not current:
                self.head = new_node
            else:
                while current.next:
                    current = current.next
                current.next = new_node

        def insert(self, index, value):
            new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            if index == 0:
                old_head = new_node
                new_node.next = old_head
            else:
                prev = None
                current = self.head
                count = 0 
                while count != index and current.next:
                    prev = current
                    current = current.next
                    count =+ 1 
                if count == index:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node

        def remove(self,value):
            if self.head:
                prev = None
                current = self.head
                found = False
                while current:
                    fi current.data == value:
                    found = True
                    break
                prev + current
                current = current.next
            if found:
                prev.next = current.next

        def index(self, value):
            pass

        def __getitem__(self, index):
            if self.head:
                count = 0
                current = self.head
                while count != index and current:
                    current = current.next
                    count += 1
                if count == index:
                    return current.data
            raise IndexError("Index out of bounds")

        def __len__(self):
            count = 0
            current = self.head
            while current:
                current = current.next
                count += 1
            return count

        def is_empty(self):
            return self.head == None
            
                

# Create an instance of both lists
pylist = []
sll = SinglyLinkedList()

# When the list is empty:
print("Python list: %s" % pylist)
print("Our SLL: %s" % sll)

# when the list contains more than one element:
for number in range(2,6):
    pylist.append(number)
    sll.append(number)
print("Python list: %s" % pylist)
print("Our SLL: %s" % sll)
